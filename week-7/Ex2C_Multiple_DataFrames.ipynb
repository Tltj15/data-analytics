# %% [markdown]
# # Exercise 2. working with multiple DataFrames

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Create a DataFrame named df_sales using the following data

# %%
data = {'Product': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East',
'West', 'North'],
'Units_Sold': [10, 15, 20, 5, 10, 15, 10, 5, 15],
'Price': [100, 200, 150, 100, 200, 150, 100, 200, 150]}

# %%
df_sales = pd.DataFrame(data)
df_sales
# Out:
#   Product Region  Units_Sold  Price
# 0       A  North          10    100
# 1       B  South          15    200
# 2       C   East          20    150
# 3       A   West           5    100
# 4       B  North          10    200
# 5       C  South          15    150
# 6       A   East          10    100
# 7       B   West           5    200
# 8       C  North          15    150

# %% [markdown]
# Add a new column Revenue to df_sales by multiplying Units_Sold and Price

# %%
df_sales['Revenue'] = df_sales['Units_Sold'] * df_sales['Price']
df_sales
# Out:
#   Product Region  Units_Sold  Price  Revenue
# 0       A  North          10    100     1000
# 1       B  South          15    200     3000
# 2       C   East          20    150     3000
# 3       A   West           5    100      500
# 4       B  North          10    200     2000
# 5       C  South          15    150     2250
# 6       A   East          10    100     1000
# 7       B   West           5    200     1000
# 8       C  North          15    150     2250

# %% [markdown]
# Use the sum function to calculate the total Units_Sold and total Revenue across all
# products and regions.

# %%
total_us = df_sales['Units_Sold'].sum()
#issues i had i was doing df_sales.sum([]), and kept getting and error
#had to add .sum at the end
total_rev = df_sales['Revenue'].sum()
print('total units', total_us)
print('total revenue', total_rev)
# Out:
# total units 105
# total revenue 16000

# %% [markdown]
# Use the mean function to calculate the average Units_Sold and average Revenue

# %%
avg_us = df_sales['Units_Sold'].mean()
avg_rev = df_sales['Revenue'].mean()
print(f'average units sold {avg_us:.2f}')
print(f'average revenue {avg_rev:.2f}')
# Out:
# average units sold 11.67
# average revenue 1777.78

# %% [markdown]
# ## Grouping Data

# %% [markdown]
# Use the groupby function to group df_sales by Product and calculate the total
# Units_Sold and total Revenue for each product

# %%
group_pro = df_sales.groupby(['Product']).sum()
group_pro
# Out:
#                  Region  Units_Sold  Price  Revenue
# Product
# A         NorthWestEast          25    300     2500
# B        SouthNorthWest          30    600     6000
# C        EastSouthNorth          50    450     7500

# %% [markdown]
# Use the groupby function to group df_sales by Region and calculate the average
# Units_Sold and average Revenue for each region

# %%
group_reg = df_sales.groupby(['Region']).mean(numeric_only=True)
#had issues with this one had to add a condition boolean
group_reg
# Out:
#         Units_Sold  Price  Revenue
# Region
# East     15.000000  125.0   2000.0
# North    11.666667  150.0   1750.0
# South    15.000000  175.0   2625.0
# West      5.000000  150.0    750.0

# %% [markdown]
# Use the groupby function to group df_sales by both Product and Region and
# calculate the sum of Units_Sold and Revenue for each combination

# %%
sum_pro_rev = df_sales.groupby(['Product', 'Region'])[['Units_Sold', 'Revenue']].sum()
sum_pro_rev
#had issues woth the double brackets i had ['units_sold]['revenue], gor error message
#same for group by([]) i had ([]'product']['region']), got error message as well
# Out:
#                 Units_Sold  Revenue
# Product Region
# A       East            10     1000
#         North           10     1000
#         West             5      500
# B       North           10     2000
#         South           15     3000
#         West             5     1000
# C       East            20     3000
#         North           15     2250
#         South           15     2250

# %% [markdown]
# ## Sorting and Ranking data

# %% [markdown]
# Sort df_sales by Units_Sold in ascending order

# %%
df_sort = df_sales.sort_values(by='Units_Sold', ascending=True)
#sort values for specific columns sort index sort by rows
print(df_sort)
# Out:
#   Product Region  Units_Sold  Price  Revenue
# 3       A   West           5    100      500
# 7       B   West           5    200     1000
# 4       B  North          10    200     2000
# 0       A  North          10    100     1000
# 6       A   East          10    100     1000
# 1       B  South          15    200     3000
# 5       C  South          15    150     2250
# 8       C  North          15    150     2250
# 2       C   East          20    150     3000

# %% [markdown]
# Sort df_sales by Revenue in descending order

# %%
df_sort = df_sales.sort_values(by= 'Revenue', ascending=False)
print(df_sort)
#ascending=True low to high
#ascending=False high to low
# Out:
#   Product Region  Units_Sold  Price  Revenue
# 1       B  South          15    200     3000
# 2       C   East          20    150     3000
# 8       C  North          15    150     2250
# 5       C  South          15    150     2250
# 4       B  North          10    200     2000
# 0       A  North          10    100     1000
# 6       A   East          10    100     1000
# 7       B   West           5    200     1000
# 3       A   West           5    100      500

# %% [markdown]
# Add a new column Revenue_Rank to df_sales, which ranks the Revenue values in
# descending order (i.e., highest revenue has rank 1)

# %%
df_sales['Revenue_Rank'] = df_sales['Revenue'].rank(ascending=False)

# %% [markdown]
# Call df_sales to review the changes

# %%
print(df_sales)
#index 1 and 2 are tied with 1.5 ranking due to have the same revenue as well as 
# index 4 and 8 tied at 3rd place
# Out:
#   Product Region  Units_Sold  Price  Revenue  Revenue_Rank
# 0       A  North          10    100     1000           7.0
# 1       B  South          15    200     3000           1.5
# 2       C   East          20    150     3000           1.5
# 3       A   West           5    100      500           9.0
# 4       B  North          10    200     2000           5.0
# 5       C  South          15    150     2250           3.5
# 6       A   East          10    100     1000           7.0
# 7       B   West           5    200     1000           7.0
# 8       C  North          15    150     2250           3.5

# %% [markdown]
# ## Merging DataFrames

# %% [markdown]
# Create a new DataFrame named df_products with the following data:
# product_data = {'Product': ['A', 'B', 'C'],
# 'Category': ['Electronics', 'Furniture', 'Appliances']}
# df_products = pd.DataFrame(product_data)

# %%
product_data = {'Product': ['A', 'B', 'C'],
    'Category': ['Electronics', 'Furniture', 'Appliances']}
df_products = pd.DataFrame(product_data)

# %% [markdown]
# Merge df_sales with df_products on the Product column, resulting in a new
# DataFrame named df_merged

# %%
df_merged = pd.merge(df_sales, df_products, on=['Product'])

# can not add '' on dataframe names or will get a type error

# %% [markdown]
# Call df_merged to review the merged DataFrame

# %%
print(df_merged)
# Out:
#   Product Region  Units_Sold  Price  Revenue  Revenue_Rank     Category
# 0       A  North          10    100     1000           7.0  Electronics
# 1       B  South          15    200     3000           1.5    Furniture
# 2       C   East          20    150     3000           1.5   Appliances
# 3       A   West           5    100      500           9.0  Electronics
# 4       B  North          10    200     2000           5.0    Furniture
# 5       C  South          15    150     2250           3.5   Appliances
# 6       A   East          10    100     1000           7.0  Electronics
# 7       B   West           5    200     1000           7.0    Furniture
# 8       C  North          15    150     2250           3.5   Appliances

# %% [markdown]
# Use groupby on df_merged to calculate the total Revenue by Category

# %%
total_rev = df_merged.groupby(['Category']).sum()
total_rev
# Out:
#             Product          Region  Units_Sold  Price  Revenue  Revenue_Rank
# Category
# Appliances      CCC  EastSouthNorth          50    450     7500           8.5
# Electronics     AAA   NorthWestEast          25    300     2500          23.0
# Furniture       BBB  SouthNorthWest          30    600     6000          13.5
