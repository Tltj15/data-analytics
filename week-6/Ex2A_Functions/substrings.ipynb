# %% [markdown]
# # exercise 2.A using built-in functions
# ## lab 1. working with names - parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]
            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
parse_and_display(test_list[1])
# Out:
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen

# %%
parse_and_display(test_list[2])
# Out:
# Full name: Ken Penn
# First name: Ken
# Last name: Penn

# %%
parse_and_display('Tracy Arista')
# Out:
# Full name: Tracy Arista
# First name: Tracy
# Last name: Arista

# %%
def parse_and_display2(name):
    part = name.split()
   
    print(f'First name: {part[0]}') #prints first name
#prints middle name and last if any
    if len(part) > 1:
        if len(part) >= 3:
            middle_name = ' '.join(part[1:-1])
            print(f'Middle name: {middle_name}')
#prints last name
        print(f'Last name: {part[-1]}')

parse_and_display2('Lorde')
parse_and_display2('Billie Eilish')
parse_and_display2('Megan Thee Stallion')
# Out:
# First name: Lorde
# First name: Billie
# Last name: Eilish
# First name: Megan
# Middle name: Thee
# Last name: Stallion

# %%
parse_and_display2('Billie Eilish')
# Out:
# Full name: Billie Eilish
# First name: Billie
# Last name: Eilish
