# %% [markdown]
# ## Lab 3. Employee data
# This lab exercise makes updates to information extracted from an employee database.

# %%
hr_list = [('0123', 'HR', 'Rebecca Yang', '69000'),
('0121', 'IT', 'Mark Blick', '67000'),
('0068', 'IT', 'Kahna Larsen', '112000'),
('0234', 'OPS', 'Jim Smith', '54000')]

#Tuple list

# %%
# Mark name change
hr_list[1] = ('0121', 'IT', 'Mark Blick-Hawley', '67000')

print(hr_list[1]) 
# i had issues with is one at first i kept using hr_list[1:2] or i tried [1][2]
# that made the most sense to me at first marks group is number 1
# and the 2 b/c the name mark is index value 2
# i had to use the whole tuple not just the name.
# Out:
# ('0121', 'IT', 'Mark Blick-Hawley', '67000')

# %%
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'OPS', 'Jim Smith', '54000')]

# %%
#update Jim new department role
hr_list[3] = ('0234', 'CS', 'Jim Smith', '60000')
print(hr_list[3])
# Out:
# ('0234', 'CS', 'Jim Smith', '60000')

# %%
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'CS', 'Jim Smith', '60000')]

# %%
#update using | separate values and salary with comma
#Employee# | DeptCode | Name | NN,NNN

print(f'{hr_list[3][0]} | {hr_list[3][1]} | {hr_list[3][2]} | {int(hr_list[3][3]):,}')
# had issues with the :, and making sure i had int() otherwise was getting errors
# Out:
# 0234 | CS | Jim Smith | 60,000

# %%
for i in hr_list:
    employee_id, department, name, salary = i
    print(f'{employee_id} | {department} | {name} | {int(salary):,}')

#used a for loop to get the whole list
# Out:
# 0123 | HR | Rebecca Yang | 69,000
# 0121 | IT | Mark Blick-Hawley | 67,000
# 0068 | IT | Kahna Larsen | 112,000
# 0234 | CS | Jim Smith | 60,000
