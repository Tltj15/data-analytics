# %% [markdown]
# # Exercise 2.C, working with defining custom functions
# ## Lab 1

# %%
def favorite_things(name, movie, music): #parameter
    first_name = name
    film = movie 
    genre = music
    print(f'My name is {name}')
    print(f'My favorite movie is {movie}')
    print(f'My favorite music genre is {music}.')

favorite_things('John', 'Twilight', 'R&B')
# you can also call the parameter favorite_things(name = 'John', movie='Twilight', music= R&B)
# Out:
# My name is John
# My favorite movie is Twilight
# My favorite music genre is R&B.

# %%
def why_im_here(purpose):
    print('Why you joined the Year Up United Data Analyst program:\n', purpose)
why_im_here('I joined the programn because I want to level up my skills to be better what I enjoy.  ')
# Out:
# Why you joined the Year Up United Data Analyst program:
#  I joined the programn because I want to level up my skills to be better what I enjoy.

# %%
def favorite_place(place, why=None):
    if why is None:
        print('My favorite place is', place)
    else:
        print('My favorite place is', place, 'because', why)

favorite_place(place = 'my home.',)
# Out:
# My favorite place is my home.

# %%
def favorite_place(place, why=None): # had issues wiht the why part had to use None wiht capital N
    # at first i was using 0 but it didnt work
    if why is None:
        print('My favorite place is', place)
    else:
        print('My favorite place is', place, 'because', why)

favorite_place(place= 'the park', why = 'my dogs can run around free')
# Out:
# My favorite place is the park because my dogs can run around free
